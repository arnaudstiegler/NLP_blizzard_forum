# %%
import pandas as pd

df = pd.read_json('data/threads.json')
df.head()
# Out:
#                                                  url  \
# 0  https://us.forums.blizzard.com/en/wow/t/player...
# 1  https://us.forums.blizzard.com/en/wow/t/no-mot...
# 2  https://us.forums.blizzard.com/en/wow/t/what-w...
# 3  https://us.forums.blizzard.com/en/wow/t/sugges...
# 4  https://us.forums.blizzard.com/en/wow/t/6-mont...
#
#                                          thread_name  \
# 0                              Players vs Developers
# 1                       No Motivation for HoA Skills
# 2  What Would be the Most Jump-the-Shark Way to E...
# 3  Suggestion: Allow us to upgrade our Flight Mas...
# 4                           6 Months Was Long Enough
#
#                                            init_post  \
# 0  It hit me earlier today when I was wondering w...
# 1  The statement “it’s Blizzard game they can do ...
# 2  Basically title.Allow us to use our whistle an...
# 3  Here is my submission.After the defeat of Azsh...
# 4  BFA released 7 months ago. I’ve experienced th...
#
#                                             comments
# 0  […pretty much.I don’t raid or dungeon so I hav...
# 1  [More like the the devs hear us but don’t care...
# 2  [OMG YES!  Though Blizz won’t do it because th...
# 3  [We find out Sylvanas is pregnant with Anduin’...
# 4  [I agree on the time frame. I as well feel the...

# %%
import spacy
spacy.load('en_core_web_sm')

from spacy.lang.en import English
parser = English()


def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk

from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
full_text = []

for index, row in df.iterrows():
    full_text.append(row['init_post'])
    full_text += row['comments']

# %%
nb_comments = len(full_text)
print("There are {} comments in the dataset".format(nb_comments))
# Out:
# There are 290121 comments in the dataset

# %%
processed_text = []

i=1
for comment in full_text:
    if(i%1000 ==0):
        print("Iteration {}".format(i))
    processed_text.append(prepare_text_for_lda(comment))
    i+=1
# Out:
# Iteration 1000
# Iteration 2000
# Iteration 3000
# Iteration 4000
# Iteration 5000
# Iteration 6000
# Iteration 7000
# Iteration 8000
# Iteration 9000
# Iteration 10000
# Iteration 11000
# Iteration 12000
# Iteration 13000
# Iteration 14000
# Iteration 15000
# Iteration 16000
# Iteration 17000
# Iteration 18000
# Iteration 19000
# Iteration 20000
# Iteration 21000
# Iteration 22000
# Iteration 23000
# Iteration 24000
# Iteration 25000
# Iteration 26000
# Iteration 27000
# Iteration 28000
# Iteration 29000
# Iteration 30000
# Iteration 31000
# Iteration 32000
# Iteration 33000
# Iteration 34000
# Iteration 35000
# Iteration 36000
# Iteration 37000
# Iteration 38000
# Iteration 39000
# Iteration 40000
# Iteration 41000
# Iteration 42000
# Iteration 43000
# Iteration 44000
# Iteration 45000
# Iteration 46000
# Iteration 47000
# Iteration 48000
# Iteration 49000
# Iteration 50000
# Iteration 51000
# Iteration 52000
# Iteration 53000
# Iteration 54000
# Iteration 55000
# Iteration 56000
# Iteration 57000
# Iteration 58000
# Iteration 59000
# Iteration 60000
# Iteration 61000
# Iteration 62000
# Iteration 63000
# Iteration 64000
# Iteration 65000
# Iteration 66000
# Iteration 67000
# Iteration 68000
# Iteration 69000
# Iteration 70000
# Iteration 71000
# Iteration 72000
# Iteration 73000
# Iteration 74000
# Iteration 75000
# Iteration 76000
# Iteration 77000
# Iteration 78000
# Iteration 79000
# Iteration 80000
# Iteration 81000
# Iteration 82000
# Iteration 83000
# Iteration 84000
# Iteration 85000
# Iteration 86000
# Iteration 87000
# Iteration 88000
# Iteration 89000
# Iteration 90000
# Iteration 91000
# Iteration 92000
# Iteration 93000
# Iteration 94000
# Iteration 95000
# Iteration 96000
# Iteration 97000
# Iteration 98000
# Iteration 99000
# Iteration 100000
# Iteration 101000
# Iteration 102000
# Iteration 103000
# Iteration 104000
# Iteration 105000
# Iteration 106000
# Iteration 107000
# Iteration 108000
# Iteration 109000
# Iteration 110000
# Iteration 111000
# Iteration 112000
# Iteration 113000
# Iteration 114000
# Iteration 115000
# Iteration 116000
# Iteration 117000
# Iteration 118000
# Iteration 119000
# Iteration 120000
# Iteration 121000
# Iteration 122000
# Iteration 123000
# Iteration 124000
# Iteration 125000
# Iteration 126000
# Iteration 127000
# Iteration 128000
# Iteration 129000
# Iteration 130000
# Iteration 131000
# Iteration 132000
# Iteration 133000
# Iteration 134000
# Iteration 135000
# Iteration 136000
# Iteration 137000
# Iteration 138000
# Iteration 139000
# Iteration 140000
# Iteration 141000
# Iteration 142000
# Iteration 143000
# Iteration 144000
# Iteration 145000
# Iteration 146000
# Iteration 147000
# Iteration 148000
# Iteration 149000
# Iteration 150000
# Iteration 151000
# Iteration 152000
# Iteration 153000
# Iteration 154000
# Iteration 155000
# Iteration 156000
# Iteration 157000
# Iteration 158000
# Iteration 159000
# Iteration 160000
# Iteration 161000
# Iteration 162000
# Iteration 163000
# Iteration 164000
# Iteration 165000
# Iteration 166000
# Iteration 167000
# Iteration 168000
# Iteration 169000
# Iteration 170000
# Iteration 171000
# Iteration 172000
# Iteration 173000
# Iteration 174000
# Iteration 175000
# Iteration 176000
# Iteration 177000
# Iteration 178000
# Iteration 179000
# Iteration 180000
# Iteration 181000
# Iteration 182000
# Iteration 183000
# Iteration 184000
# Iteration 185000
# Iteration 186000
# Iteration 187000
# Iteration 188000
# Iteration 189000
# Iteration 190000
# Iteration 191000
# Iteration 192000
# Iteration 193000
# Iteration 194000
# Iteration 195000
# Iteration 196000
# Iteration 197000
# Iteration 198000
# Iteration 199000
# Iteration 200000
# Iteration 201000
# Iteration 202000
# Iteration 203000
# Iteration 204000
# Iteration 205000
# Iteration 206000
# Iteration 207000
# Iteration 208000
# Iteration 209000
# Iteration 210000
# Iteration 211000
# Iteration 212000
# Iteration 213000
# Iteration 214000
# Iteration 215000
# Iteration 216000
# Iteration 217000
# Iteration 218000
# Iteration 219000
# Iteration 220000
# Iteration 221000
# Iteration 222000
# Iteration 223000
# Iteration 224000
# Iteration 225000
# Iteration 226000
# Iteration 227000
# Iteration 228000
# Iteration 229000
# Iteration 230000
# Iteration 231000
# Iteration 232000
# Iteration 233000
# Iteration 234000
# Iteration 235000
# Iteration 236000
# Iteration 237000
# Iteration 238000
# Iteration 239000
# Iteration 240000
# Iteration 241000
# Iteration 242000
# Iteration 243000
# Iteration 244000
# Iteration 245000
# Iteration 246000
# Iteration 247000
# Iteration 248000
# Iteration 249000
# Iteration 250000
# Iteration 251000
# Iteration 252000
# Iteration 253000
# Iteration 254000
# Iteration 255000
# Iteration 256000
# Iteration 257000
# Iteration 258000
# Iteration 259000
# Iteration 260000
# Iteration 261000
# Iteration 262000
# Iteration 263000
# Iteration 264000
# Iteration 265000
# Iteration 266000
# Iteration 267000
# Iteration 268000
# Iteration 269000
# Iteration 270000
# Iteration 271000
# Iteration 272000
# Iteration 273000
# Iteration 274000
# Iteration 275000
# Iteration 276000
# Iteration 277000
# Iteration 278000
# Iteration 279000
# Iteration 280000
# Iteration 281000
# Iteration 282000
# Iteration 283000
# Iteration 284000
# Iteration 285000
# Iteration 286000
# Iteration 287000
# Iteration 288000
# Iteration 289000
# Iteration 290000

# %%
from gensim import corpora
dictionary = corpora.Dictionary(processed_text)
corpus = [dictionary.doc2bow(text) for text in processed_text]

import pickle
pickle.dump(corpus, open('topic_modeling/corpus.pkl', 'wb'))
dictionary.save('topic_modeling/dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('topic_modeling/model5.gensim')
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(topic[1])

# %%
import re

ldamodel.load('topic_modeling/model5.gensim')
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(re.findall(r'"(.*?)"', topic[1]))
# Out:
# ['reason', 'problem', 'break', 'agree', 'forget', 'absolutely', 'issue', 'disagree', 'love', 'leave']
# ['look', 'flying', 'account', 'cause', 'happy', 'report', 'minutes', 'remove', 'healing', 'green']
# ['people', 'player', 'would', 'group', 'guild', 'server', 'friend', 'think', 'really', 'blizzard']
# ['make', 'sense', 'happen', 'times', 'second', 'going', 'learn', 'expect', 'exactly', 'enough']
# ['level', 'character', 'expansion', 'content', 'legion', 'leveling', 'enjoy', 'quest', 'patch', 'grind']
# ['horde', 'alliance', 'sylvanas', 'faction', 'blood', 'kill', 'would', 'character', 'attack', 'saurfang']
# ['right', 'sound', 'super', 'stick', 'waiting', 'throw', 'maybe', 'starting', 'bunch', 'pandaren']
# ['elves', 'race', 'gnome', 'night', 'troll', 'ally', 'goblin', 'hunter', 'undead', 'tauren']
# ['think', 'forum', 'people', 'something', 'someone', 'point', 'would', 'wrong', 'saying', 'nothing']
# ['dungeon', 'raid', 'mythic', 'normal', 'heroic', 'piece', 'check', 'raider', 'casual', 'reply']
# ['rogue', 'question', 'queue', 'control', 'answer', 'healer', 'damage', 'tank', 'watch', 'voice']
# ['druid', 'paladin', 'warrior', 'human', 'warlock', 'class', 'light', 'shaman', 'humans', 'priest']
# ['allow', 'portal', 'female', 'thank', 'worgen', 'animation', 'update', 'speak', 'secret', 'important']
# ['really', 'never', 'though', 'first', 'always', 'thing', 'still', 'since', 'would', 'remember']
# ['would', 'class', 'classic', 'could', 'change', 'better', 'ability', 'think', 'weapon', 'option']
# ['mount', 'blizzard', 'month', 'money', 'years', 'game', 'release', 'spend', 'water', 'would']
# ['pretty', 'every', 'everyone', 'everything', 'talking', 'call', 'design', 'single', 'except', 'know']
# ['world', 'fight', 'story', 'forsake', 'power', 'death', 'would', 'azeroth', 'warcraft', 'battle']
# ['quest', 'getting', 'reward', 'drop', 'complain', 'around', 'chance', 'island', 'lucky', 'bonus']
# ['warmode', 'thread', 'person', 'sorry', 'support', 'title', 'thanks', 'threads', 'another', 'ignore']

# %%
ldamodel.show_topics(num_topics=20, num_words=10, log=False, formatted=True)
# Out:
# [(0,
#   '0.045*"reason" + 0.043*"problem" + 0.042*"break" + 0.042*"agree" + 0.030*"forget" + 0.024*"absolutely" + 0.020*"issue" + 0.017*"disagree" + 0.016*"love" + 0.014*"leave"'),
#  (1,
#   '0.060*"look" + 0.060*"flying" + 0.039*"account" + 0.033*"cause" + 0.031*"happy" + 0.029*"report" + 0.027*"minutes" + 0.024*"remove" + 0.023*"healing" + 0.021*"green"'),
#  (2,
#   '0.077*"people" + 0.043*"player" + 0.025*"would" + 0.020*"group" + 0.015*"guild" + 0.015*"server" + 0.013*"friend" + 0.011*"think" + 0.010*"really" + 0.009*"blizzard"'),
#  (3,
#   '0.043*"make" + 0.039*"sense" + 0.035*"happen" + 0.031*"times" + 0.027*"second" + 0.022*"going" + 0.020*"learn" + 0.016*"expect" + 0.015*"exactly" + 0.015*"enough"'),
#  (4,
#   '0.065*"level" + 0.041*"character" + 0.040*"expansion" + 0.036*"content" + 0.021*"legion" + 0.018*"leveling" + 0.015*"enjoy" + 0.014*"quest" + 0.013*"patch" + 0.013*"grind"'),
#  (5,
#   '0.138*"horde" + 0.121*"alliance" + 0.046*"sylvanas" + 0.043*"faction" + 0.033*"blood" + 0.024*"kill" + 0.023*"would" + 0.015*"character" + 0.014*"attack" + 0.014*"saurfang"'),
#  (6,
#   '0.100*"right" + 0.047*"sound" + 0.027*"super" + 0.024*"stick" + 0.024*"waiting" + 0.022*"throw" + 0.021*"maybe" + 0.018*"starting" + 0.018*"bunch" + 0.018*"pandaren"'),
#  (7,
#   '0.085*"elves" + 0.065*"race" + 0.056*"gnome" + 0.054*"night" + 0.045*"troll" + 0.037*"ally" + 0.036*"goblin" + 0.035*"hunter" + 0.034*"undead" + 0.025*"tauren"'),
#  (8,
#   '0.043*"think" + 0.030*"forum" + 0.029*"people" + 0.026*"something" + 0.025*"someone" + 0.024*"point" + 0.023*"would" + 0.018*"wrong" + 0.016*"saying" + 0.015*"nothing"'),
#  (9,
#   '0.075*"dungeon" + 0.069*"raid" + 0.046*"mythic" + 0.031*"normal" + 0.028*"heroic" + 0.023*"piece" + 0.021*"check" + 0.021*"raider" + 0.019*"casual" + 0.019*"reply"'),
#  (10,
#   '0.041*"rogue" + 0.034*"question" + 0.029*"queue" + 0.026*"control" + 0.025*"answer" + 0.025*"healer" + 0.024*"damage" + 0.020*"tank" + 0.018*"watch" + 0.016*"voice"'),
#  (11,
#   '0.047*"druid" + 0.041*"paladin" + 0.034*"warrior" + 0.034*"human" + 0.029*"warlock" + 0.029*"class" + 0.028*"light" + 0.024*"shaman" + 0.024*"humans" + 0.023*"priest"'),
#  (12,
#   '0.032*"allow" + 0.032*"portal" + 0.026*"female" + 0.023*"thank" + 0.021*"worgen" + 0.018*"animation" + 0.018*"update" + 0.018*"speak" + 0.014*"secret" + 0.013*"important"'),
#  (13,
#   '0.061*"really" + 0.046*"never" + 0.033*"though" + 0.030*"first" + 0.028*"always" + 0.027*"thing" + 0.026*"still" + 0.023*"since" + 0.022*"would" + 0.021*"remember"'),
#  (14,
#   '0.079*"would" + 0.052*"class" + 0.044*"classic" + 0.029*"could" + 0.026*"change" + 0.025*"better" + 0.022*"ability" + 0.017*"think" + 0.016*"weapon" + 0.015*"option"'),
#  (15,
#   '0.090*"mount" + 0.060*"blizzard" + 0.029*"month" + 0.028*"money" + 0.024*"years" + 0.022*"game" + 0.017*"release" + 0.016*"spend" + 0.016*"water" + 0.014*"would"'),
#  (16,
#   '0.053*"pretty" + 0.042*"every" + 0.032*"everyone" + 0.032*"everything" + 0.020*"talking" + 0.019*"call" + 0.017*"design" + 0.016*"single" + 0.016*"except" + 0.015*"know"'),
#  (17,
#   '0.036*"world" + 0.025*"fight" + 0.025*"story" + 0.022*"forsake" + 0.022*"power" + 0.021*"death" + 0.017*"would" + 0.017*"azeroth" + 0.016*"warcraft" + 0.013*"battle"'),
#  (18,
#   '0.055*"quest" + 0.030*"getting" + 0.025*"reward" + 0.022*"drop" + 0.019*"complain" + 0.015*"around" + 0.014*"chance" + 0.014*"island" + 0.014*"lucky" + 0.014*"bonus"'),
#  (19,
#   '0.053*"warmode" + 0.051*"thread" + 0.043*"person" + 0.037*"sorry" + 0.037*"support" + 0.037*"title" + 0.035*"thanks" + 0.025*"threads" + 0.023*"another" + 0.022*"ignore"')]

# %%
ldamodel.top_topics()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e5e2c6244351> in <module>
# ----> 1 ldamodel.top_topics()
#
# ~/miniconda3/envs/forum_scraping/lib/python3.6/site-packages/gensim/models/ldamodel.py in top_topics(self, corpus, texts, dictionary, window_size, coherence, topn, processes)
#    1266             model=self, corpus=corpus, texts=texts, dictionary=dictionary,
#    1267             window_size=window_size, coherence=coherence, topn=topn,
# -> 1268             processes=processes
#    1269         )
#    1270         coherence_scores = cm.get_coherence_per_topic()
#
# ~/miniconda3/envs/forum_scraping/lib/python3.6/site-packages/gensim/models/coherencemodel.py in __init__(self, model, topics, texts, corpus, dictionary, window_size, keyed_vectors, coherence, topn, processes)
#     166         self.keyed_vectors = keyed_vectors
#     167         if keyed_vectors is None and texts is None and corpus is None:
# --> 168             raise ValueError("One of texts or corpus has to be provided.")
#     169
#     170         # Check if associated dictionary is provided.
#
# ValueError: One of texts or corpus has to be provided.
